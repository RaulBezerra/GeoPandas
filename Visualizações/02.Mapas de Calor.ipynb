# %% [markdown]
# ##Mapas de Calor
#
# Exemplos:
#
# https://github.com/python-visualization/folium/blob/main/examples/Heatmap.ipynb

# %%
# !pip install geopandas

# %%
import geopandas as gpd
import folium

# %%
rj = gpd.read_file('/content/drive/MyDrive/Colab Notebooks/Python 16 - Geopandas pt1/RJ/RJ-MUNIC/RJ-MUNIC.shp')
geo_dados = gpd.read_file('drive/MyDrive/Colab Notebooks/Python 16 - Geopandas pt1/RJ/DATASET/DATASET.shp')
setor= gpd.read_file('drive/MyDrive/Colab Notebooks/Python 16 - Geopandas pt1/RJ/RJ-SETOR/RJ-SETOR.shp')
bairro = gpd.read_file('/content/drive/MyDrive/Colab Notebooks/Python 16 - Geopandas pt1/RJ/RJ-BAIRRO/RJ-BAIRRO.shp')

# %%
crs = {'init': 'epsg:4326'}

# %%
rj = rj.to_crs(crs)
geo_dados = geo_dados.to_crs(crs)
setor = setor.to_crs(crs)
bairro = bairro.to_crs(crs)

# %%
setor.fillna(0, inplace = True)

# %%
y = rj.centroid.y.iloc[0]
x = rj.centroid.x.iloc[0]

# %%
setor.head(1)
# Out:
#       ID1  ...                                           geometry
# 0  401513  ...  POLYGON ((-43.18656 -22.91025, -43.18626 -22.9...
#
# [1 rows x 47 columns]

# %%
data = []
for i in range (len(setor)):
  data.append([setor['geometry'][i].centroid.y, setor['geometry'][i].centroid.x, setor['V002'][i]/setor['V002'].max()])

# %%
data

# %%
from folium.plugins import HeatMap
base = folium.Map([y,x], tiles="OpenStreetMap", zoom_start=11)

HeatMap(data, name = 'População').add_to(base)

folium.LayerControl().add_to(base)

base.save('Dataset Marcadores HeatMap.html')
base
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...
